# %% [markdown]
# <a href="https://colab.research.google.com/github/SusantaBanerjee/ML-College/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-590f69c6-742a-475a-8834-568c1a83a2f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-590f69c6-742a-475a-8834-568c1a83a2f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving letters.csv to letters.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['letters.csv']))

# %%
df.head()
# Out:
#   lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0     T      2      8      3     5      1      8     13      0      6      6
# 1     I      5     12      3     7      2     10      5      5      4     13
# 2     D      4     11      6     8      6     10      6      2      6     10
# 3     N      7     11      6     6      3      5      9      4      6      4
# 4     G      2      1      3     1      1      8      6      6      6      6
#
#    x2ybar  xy2bar  x-ege  xegvy  y-ege  yegvx
# 0      10       8      0      8      0      8
# 1       3       9      2      8      4     10
# 2       3       7      3      7      3      9
# 3       4      10      6     10      2      8
# 4       5       9      1      7      5     10

# %%
df.describe()
# Out:
#               x-box         y-box         width         high         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#               x-bar         y-bar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
df.columns
# Out:
# Index(['lettr', 'x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar',
#        'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'x-ege', 'xegvy',
#        'y-ege', 'yegvx'],
#       dtype='object')

# %%
sns.boxplot(x="lettr",y="x-box",data=df,palette = "hls")
sns.boxplot(x="y-box",y="lettr",data=df,palette = "hls")
sns.pairplot(data=df)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size = 0.3)
test.head()
train_X = train.iloc[:,1:]
train_y = train.iloc[:,0]
test_X  = test.iloc[:,1:]
test_y  = test.iloc[:,0]

# %%
# Create SVM classification object 
# 'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'

# kernel = linear

# %%
model_linear = SVC(kernel = "linear")
model_linear.fit(train_X,train_y)
pred_test_linear = model_linear.predict(test_X)

# %%
np.mean(pred_test_linear==test_y)
# Out:
# 0.8483333333333334

# %%
# Kernel = poly
model_poly = SVC(kernel = "poly")
model_poly.fit(train_X,train_y)
pred_test_poly = model_poly.predict(test_X)

# %%
np.mean(pred_test_poly==test_y)
# Out:
# 0.9386666666666666

# %%
# kernel = rbf
model_rbf = SVC(kernel = "rbf")
model_rbf.fit(train_X,train_y)
pred_test_rbf = model_rbf.predict(test_X)

# %%
np.mean(pred_test_rbf==test_y)
# Out:
# 0.9173333333333333
